# %% [markdown]
# # Separable segmentation
#
# > The idea is to use a set of grouped convolution to perform the final segmentation in the last layer.

# %%
import os; os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
from pathlib import Path
from itertools import product
from typing import Tuple

import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import layers
import cv2
import wandb
from wandb.keras import WandbCallback

# %% [markdown]
# ## Data Loading
#
# > We will be using CityScapes as a baseline.

# %% [markdown]
# The different training, validation and test subsets are divided in their correspondent folders:

# %%
path_root = Path("/media/disk/databases/dn_segmentation/cityscapes")
path_train = path_root / "train_data"
path_val = path_root / "validation_data"
path_test = path_root / "test_data"

# %% [markdown]
# We will now build a set of generators to load the data:

# %%
def get_label_path_from_img(path_img):
    path_label = str(path_img).split("_")
    path_label[-1] = "gtFine_color.png"
    path_label = "_".join(path_label)
    path_label = path_label.replace("images", "labels")
    path_label = Path(path_label)
    return path_label

# %%
def train_gen():
    for path_img in (path_train/"images").glob("*.png"):
        path_label = get_label_path_from_img(path_img)

        ## Load the images
        img = cv2.imread(str(path_img))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, dsize=(256,128))
        label = cv2.imread(str(path_label))
        label = cv2.cvtColor(label, cv2.COLOR_BGR2RGB)
        label = cv2.resize(label, dsize=(256,128), interpolation=cv2.INTER_NEAREST)
        yield img, label

# %%
def val_gen():
    for path_img in (path_val/"images").glob("*.png"):
        path_label = get_label_path_from_img(path_img)

        ## Load the images
        img = cv2.imread(str(path_img))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, dsize=(256,128))
        label = cv2.imread(str(path_label))
        label = cv2.cvtColor(label, cv2.COLOR_BGR2RGB)
        label = cv2.resize(label, dsize=(256,128), interpolation=cv2.INTER_NEAREST)
        yield img, label

# %%
a, b = next(train_gen())
a.shape, b.shape
# Out:
# ((128, 256, 3), (128, 256, 3))

# %%
fig, axes = plt.subplots(1,2,figsize=(9,4))

axes[0].imshow(a)
axes[1].imshow(b)
for ax in axes: ax.axis("off")
plt.show()

# %% [markdown]
# ### Turn the labels into a sparse representation
#
# > The labels are loaded as colors, but now we need to turn them into sparse representations to be able to train our network.

# %% [markdown]
# First we will be obtaining the individual colors in the images:

# %%
colors = np.array([(0, 0, 0), (111, 74, 0), (81, 0, 81), (128, 64, 128), (244, 35, 232), (250, 170, 160), (230, 150, 140), (70, 70, 70), 
                   (102, 102, 156), (190, 153, 153), (180, 165, 180), (150, 100, 100), (150, 120, 90), (153, 153, 153), (250, 170, 30), (220, 220, 0), (107, 142, 35), 
                   (152, 251, 152), (70, 130, 180), (220, 20, 60), (255, 0, 0), ( 0, 0, 142), ( 0, 0, 70), (0, 60, 100), (0, 0, 90), (0, 0, 110), (0, 80, 100), (0, 0, 230), 
                   (119, 11, 32), (0, 0, 142)], dtype = np.int32)
colors = set([tuple(c) for c in colors])
len(colors)
# Out:
# 29

# %% [markdown]
# Now we can build a dictionary mapping each color into one integer:

# %%
color2label = {color:i for i,color in enumerate(colors)}
label2color = {i:color for i,color in enumerate(colors)}
len(color2label)#, label2color
# Out:
# 29

# %% [markdown]
# Finally, we can convert the label:

# %%
def prepare_label(label):
    new_label = np.empty(shape=label.shape[:-1])
    for i, j in product(range(label.shape[0]), range(label.shape[1])):
        color = label[i,j]
        new_label[i,j] = color2label[tuple(color)]
    return new_label

# %%
def prepare_label_one_hot(label):
    new_label = np.zeros(shape=(*label.shape[:-1], len(colors)))
    for i, j in product(range(label.shape[0]), range(label.shape[1])):
        color = label[i,j]
        idx = color2label[tuple(color)]
        new_label[i,j,idx] = 1
    return new_label

# %%
def one_hot_to_sparse(label):
    """Turns a one-hot encoded label into a sparse one."""
    return np.argmax(label, axis=-1)

# %% [markdown]
# ## Building the `Dataset`

# %%
def train_gen():
    for path_img in (path_train/"images").glob("*.png"):
        path_label = get_label_path_from_img(path_img)

        ## Load the images
        img = cv2.imread(str(path_img))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, dsize=(256,128))
        label = cv2.imread(str(path_label))
        label = cv2.cvtColor(label, cv2.COLOR_BGR2RGB)
        label = cv2.resize(label, dsize=(256,128), interpolation=cv2.INTER_NEAREST)

        ## Prepare the labels
        # label = prepare_label(label)
        label = prepare_label_one_hot(label)
        # label = tf.expand_dims(label, -1)
        
        yield img/255.0, label

# %%
def val_gen():
    for path_img in (path_val/"images").glob("*.png"):
        path_label = get_label_path_from_img(path_img)

        ## Load the images
        img = cv2.imread(str(path_img))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, dsize=(256,128))
        label = cv2.imread(str(path_label))
        label = cv2.cvtColor(label, cv2.COLOR_BGR2RGB)
        label = cv2.resize(label, dsize=(256,128), interpolation=cv2.INTER_NEAREST)

        ## Prepare the labels
        # label = prepare_label(label)
        label = prepare_label_one_hot(label)
        # label = tf.expand_dims(label, -1)
        
        yield img/255.0, label

# %%
a, b = next(train_gen())
a.shape, b.shape
# Out:
# ((128, 256, 3), (128, 256, 29))

# %%
dst_train = tf.data.Dataset.from_generator(
                            train_gen,
                            output_signature=(
                                tf.TensorSpec(a.shape, tf.float32),
                                tf.TensorSpec(b.shape, tf.int32),
                            ))

# %%
dst_val = tf.data.Dataset.from_generator(
                            val_gen,
                            output_signature=(
                                tf.TensorSpec(a.shape, tf.float32),
                                tf.TensorSpec(b.shape, tf.int32),
                            ))

# %% [markdown]
# ## Defining the model
#
# > The important part is going to be at the last part of the model.

# %%
config = {
    "batch_size": 64,
    "epochs": 50,
    "pre_last_activation": "sigmoid"
}

# %%
wandb.init(project="segmentation_test",
           name="Sigmoid",
           config=config)
config = wandb.config
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: jorgvt. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq</code>
# Syncing run <strong><a href="https://wandb.ai/jorgvt/segmentation_test/runs/cggcffhq" target="_blank">Sigmoid</a></strong> to <a href="https://wandb.ai/jorgvt/segmentation_test" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %%
# inputs = tf.keras.Input(shape=(1024,2048,3))
inputs = tf.keras.Input(shape=(128, 256,3))
# resize = layers.Resizing(128, 256)
conv1_e = layers.Conv2D(32, kernel_size=5, strides=1, padding="same", activation="relu")
conv2_e = layers.Conv2D(64, kernel_size=5, strides=1, padding="same", activation="relu")
conv3_e = layers.Conv2D(128, kernel_size=5, strides=1, padding="same", activation="relu")
pooling = layers.MaxPooling2D(2)
upsampling = layers.UpSampling2D(2)
conv2_d = layers.Conv2D(32, kernel_size=5, strides=1, padding="same", activation="relu")
conv1_d = layers.Conv2D(len(color2label)*3, kernel_size=5, strides=1, padding="same", activation=config.pre_last_activation)
classifier = layers.Conv2D(len(color2label), kernel_size=1, groups=len(color2label), strides=1, padding="same", activation="softmax")

## Encoder
# inputs_resized = resize(inputs)
# output_1e = conv1_e(inputs_resized)
output_1e = conv1_e(inputs)
output_2e = conv2_e(pooling(output_1e))
output_3e = conv3_e(pooling(output_2e))

## Decoder

upsampled_3 = upsampling(output_3e)
output_2d = conv2_d(tf.concat([output_2e, upsampled_3], axis=-1))
upsampled_2 = upsampling(output_2d)
output_1d = conv1_d(tf.concat([output_1e, upsampled_2], axis=-1))

## Separable classifier
output_final = classifier(output_1d)

## Model
model = tf.keras.Model(inputs, output_final)
model.compile(optimizer="adam",
              loss=tf.losses.CategoricalCrossentropy(from_logits=False),
              # loss="mae",
              metrics=["accuracy",
                    #    tf.keras.metrics.IoU(num_classes=len(colors),
                    #                         target_class_ids=list(range(len(colors)))),
                       ])

# %% [markdown]
# ## Training the model

# %%
def prepare_masks_wandb(image, 
                        label, # one-hot encoeded.
                        pred, # one-hot encoeded.,
                        class_labels,
                        ):
    label = one_hot_to_sparse(label)
    pred = one_hot_to_sparse(pred)
    mask_img = wandb.Image(image, masks={
        "predictions": {
            "mask_data": pred,
            "class_labels": class_labels
        },
        "ground_truth": {
            "mask_data": label,
            "class_labels": class_labels,
        }
        })
    return mask_img

# %%
class SegmentationMaskLogger(tf.keras.callbacks.Callback):
    """Callback to log the segmentation masks properly into WandB."""

    def __init__(self, 
                 data: Tuple, # (X, Y) tuple.
                 prefix: str = "",
                 ):
        self.data = data
        self.prefix = prefix
        self.class_labels = {k:str(v) for k,v in label2color.items()}
    
    def on_epoch_end(self,
                     epoch,
                     logs=None,
                     ):
        preds = model.predict(self.data[0], verbose=0)
        results = [prepare_masks_wandb(X, Y, pred, self.class_labels) for X, Y, pred in zip(self.data[0], self.data[1], preds)]
        wandb.log({f"{self.prefix}results":results})

# %%
history = model.fit(dst_train.batch(config.batch_size), epochs=config.epochs,
                    validation_data=dst_val.batch(config.batch_size),
                    callbacks=[WandbCallback(monitor="val_loss",
                                             mode="min",
                                             save_weights_only=True,
                                             ),
                    SegmentationMaskLogger(data=dst_train.batch(8).take(1).get_single_element(), prefix="train_"),
                    SegmentationMaskLogger(data=dst_val.batch(8).take(1).get_single_element(), prefix="val_"),
                    ])
# Out:
# Epoch 1/50
# 47/47 [==============================] - 1228s 26s/step - loss: 3.0833 - accuracy: 0.0846 - val_loss: 3.0056 - val_accuracy: 0.0963
# Epoch 2/50
# 47/47 [==============================] - 1037s 22s/step - loss: 2.9589 - accuracy: 0.0855 - val_loss: 2.9044 - val_accuracy: 0.0963
# Epoch 3/50
# 47/47 [==============================] - 1037s 22s/step - loss: 2.8606 - accuracy: 0.1123 - val_loss: 2.8120 - val_accuracy: 0.1999
# Epoch 4/50
# 47/47 [==============================] - 1022s 22s/step - loss: 2.7612 - accuracy: 0.2103 - val_loss: 2.7108 - val_accuracy: 0.1999
# Epoch 5/50
# 47/47 [==============================] - 1020s 22s/step - loss: 2.6606 - accuracy: 0.2103 - val_loss: 2.6214 - val_accuracy: 0.1999
# Epoch 6/50
# 47/47 [==============================] - 1025s 22s/step - loss: 2.5741 - accuracy: 0.2104 - val_loss: 2.5445 - val_accuracy: 0.2001
# Epoch 7/50
# 47/47 [==============================] - 1034s 22s/step - loss: 2.4792 - accuracy: 0.4349 - val_loss: 2.4333 - val_accuracy: 0.4894
# Epoch 8/50
# 47/47 [==============================] - 1027s 22s/step - loss: 2.3523 - accuracy: 0.4992 - val_loss: 2.3085 - val_accuracy: 0.4799
# Epoch 9/50
# 47/47 [==============================] - 1038s 22s/step - loss: 2.2334 - accuracy: 0.4952 - val_loss: 2.1910 - val_accuracy: 0.5025
# Epoch 10/50
# 47/47 [==============================] - 1025s 22s/step - loss: 2.1223 - accuracy: 0.5228 - val_loss: 2.0947 - val_accuracy: 0.5106
# Epoch 11/50
# 47/47 [==============================] - 1035s 22s/step - loss: 2.0168 - accuracy: 0.5457 - val_loss: 1.9858 - val_accuracy: 0.5678
# Epoch 12/50
# 47/47 [==============================] - 1027s 22s/step - loss: 1.9155 - accuracy: 0.5775 - val_loss: 1.8928 - val_accuracy: 0.5750
# Epoch 13/50
# 47/47 [==============================] - 1030s 22s/step - loss: 1.8341 - accuracy: 0.5876 - val_loss: 1.8250 - val_accuracy: 0.5956
# Epoch 14/50
# 47/47 [==============================] - 1034s 22s/step - loss: 1.7547 - accuracy: 0.6000 - val_loss: 1.7350 - val_accuracy: 0.5962
# Epoch 15/50
# 47/47 [==============================] - 1093s 23s/step - loss: 1.6724 - accuracy: 0.6199 - val_loss: 1.6740 - val_accuracy: 0.6556
# Epoch 16/50
# 47/47 [==============================] - 1087s 23s/step - loss: 1.6024 - accuracy: 0.6810 - val_loss: 1.6099 - val_accuracy: 0.6902
# Epoch 17/50
# 47/47 [==============================] - 1096s 23s/step - loss: 1.5304 - accuracy: 0.7043 - val_loss: 1.5355 - val_accuracy: 0.7078
# Epoch 18/50
# 47/47 [==============================] - 1090s 23s/step - loss: 1.4653 - accuracy: 0.7177 - val_loss: 1.4697 - val_accuracy: 0.7204
# Epoch 19/50
# 47/47 [==============================] - 1090s 23s/step - loss: 1.4032 - accuracy: 0.7303 - val_loss: 1.4097 - val_accuracy: 0.7263
# Epoch 20/50
# 47/47 [==============================] - 1091s 23s/step - loss: 1.3433 - accuracy: 0.7401 - val_loss: 1.3642 - val_accuracy: 0.7316
# Epoch 21/50
# 47/47 [==============================] - 1088s 23s/step - loss: 1.2942 - accuracy: 0.7464 - val_loss: 1.3152 - val_accuracy: 0.7384
# Epoch 22/50
# 47/47 [==============================] - 1085s 23s/step - loss: 1.2490 - accuracy: 0.7528 - val_loss: 1.2667 - val_accuracy: 0.7445
# Epoch 23/50
# 47/47 [==============================] - 1088s 23s/step - loss: 1.2074 - accuracy: 0.7559 - val_loss: 1.2321 - val_accuracy: 0.7512
# Epoch 24/50
# 47/47 [==============================] - 1086s 23s/step - loss: 1.1681 - accuracy: 0.7614 - val_loss: 1.1979 - val_accuracy: 0.7530
# Epoch 25/50
# 47/47 [==============================] - 1087s 23s/step - loss: 1.1324 - accuracy: 0.7669 - val_loss: 1.1622 - val_accuracy: 0.7567
# Epoch 26/50
# 47/47 [==============================] - 1083s 23s/step - loss: 1.1008 - accuracy: 0.7711 - val_loss: 1.1178 - val_accuracy: 0.7624
# Epoch 27/50
# 47/47 [==============================] - 1090s 23s/step - loss: 1.0704 - accuracy: 0.7751 - val_loss: 1.0922 - val_accuracy: 0.7685
# Epoch 28/50
# 47/47 [==============================] - 1085s 23s/step - loss: 1.0429 - accuracy: 0.7789 - val_loss: 1.0670 - val_accuracy: 0.7711
# Epoch 29/50
# 47/47 [==============================] - 1046s 22s/step - loss: 1.0161 - accuracy: 0.7835 - val_loss: 1.0621 - val_accuracy: 0.7669
# Epoch 30/50
# 47/47 [==============================] - 1026s 22s/step - loss: 0.9995 - accuracy: 0.7839 - val_loss: 1.0248 - val_accuracy: 0.7765
# Epoch 31/50
# 47/47 [==============================] - 1026s 22s/step - loss: 0.9772 - accuracy: 0.7870 - val_loss: 1.0069 - val_accuracy: 0.7777
# Epoch 32/50
# 47/47 [==============================] - 1027s 22s/step - loss: 0.9565 - accuracy: 0.7904 - val_loss: 0.9823 - val_accuracy: 0.7787
# Epoch 33/50
# 47/47 [==============================] - 1023s 22s/step - loss: 0.9372 - accuracy: 0.7926 - val_loss: 0.9655 - val_accuracy: 0.7808
# Epoch 34/50
# 47/47 [==============================] - 1043s 22s/step - loss: 0.9221 - accuracy: 0.7939 - val_loss: 0.9527 - val_accuracy: 0.7821
# Epoch 35/50
# 47/47 [==============================] - 1025s 22s/step - loss: 0.9055 - accuracy: 0.7963 - val_loss: 0.9449 - val_accuracy: 0.7805
# Epoch 36/50
# 47/47 [==============================] - 1026s 22s/step - loss: 0.8892 - accuracy: 0.7986 - val_loss: 0.9184 - val_accuracy: 0.7857
# Epoch 37/50
# 47/47 [==============================] - 1023s 22s/step - loss: 0.8754 - accuracy: 0.8000 - val_loss: 0.9053 - val_accuracy: 0.7874
# Epoch 38/50
# 47/47 [==============================] - 1027s 22s/step - loss: 0.8611 - accuracy: 0.8021 - val_loss: 0.8933 - val_accuracy: 0.7896
# Epoch 39/50
# 47/47 [==============================] - 1024s 22s/step - loss: 0.8512 - accuracy: 0.8028 - val_loss: 0.8855 - val_accuracy: 0.7908
# Epoch 40/50
# 47/47 [==============================] - 1023s 22s/step - loss: 0.8373 - accuracy: 0.8054 - val_loss: 0.8753 - val_accuracy: 0.7918
# Epoch 41/50
# 47/47 [==============================] - 1026s 22s/step - loss: 0.8304 - accuracy: 0.8051 - val_loss: 0.8713 - val_accuracy: 0.7920
# Epoch 42/50
# 47/47 [==============================] - 1343s 29s/step - loss: 0.8184 - accuracy: 0.8075 - val_loss: 0.8570 - val_accuracy: 0.7935
# Epoch 43/50
# 47/47 [==============================] - 1441s 31s/step - loss: 0.8076 - accuracy: 0.8089 - val_loss: 0.8502 - val_accuracy: 0.7944
# Epoch 44/50
# 47/47 [==============================] - 1417s 30s/step - loss: 0.7984 - accuracy: 0.8100 - val_loss: 0.8457 - val_accuracy: 0.7945
# Epoch 45/50
# 47/47 [==============================] - 1417s 30s/step - loss: 0.7877 - accuracy: 0.8115 - val_loss: 0.8400 - val_accuracy: 0.7947
# Epoch 46/50
# 47/47 [==============================] - 1409s 30s/step - loss: 0.7781 - accuracy: 0.8125 - val_loss: 0.8328 - val_accuracy: 0.7953
# Epoch 47/50
# 47/47 [==============================] - 1400s 30s/step - loss: 0.7695 - accuracy: 0.8136 - val_loss: 0.8243 - val_accuracy: 0.7966
# Epoch 48/50
# 47/47 [==============================] - 1394s 30s/step - loss: 0.7608 - accuracy: 0.8147 - val_loss: 0.8151 - val_accuracy: 0.7977
# Epoch 49/50
# 47/47 [==============================] - 1405s 30s/step - loss: 0.7537 - accuracy: 0.8153 - val_loss: 0.8167 - val_accuracy: 0.7962
# Epoch 50/50
# 47/47 [==============================] - 1409s 30s/step - loss: 0.7543 - accuracy: 0.8134 - val_loss: 0.8050 - val_accuracy: 0.7976
# wandb: WARNING The save_model argument by default saves the model in the HDF5 format that cannot save custom objects like subclassed models and custom layers. This behavior will be deprecated in a future release in favor of the SavedModel format. Meanwhile, the HDF5 model is saved as W&B files and the SavedModel as W&B Artifacts.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.1s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.1s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.1s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.1s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.1s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.1s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best/assets
# wandb: Adding directory to artifact (/media/disk/users-muten/vitojor/CycleGTA/01_Segmentation/wandb/run-20221128_095332-cggcffhq/files/model-best)... Done. 0.2s

# %%
wandb.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.8134</td></tr><tr><td>best_epoch</td><td>49</td></tr><tr><td>best_val_loss</td><td>0.80496</td></tr><tr><td>epoch</td><td>49</td></tr><tr><td>loss</td><td>0.75429</td></tr><tr><td>val_accuracy</td><td>0.79757</td></tr><tr><td>val_loss</td><td>0.80496</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">Sigmoid</strong>: <a href="https://wandb.ai/jorgvt/segmentation_test/runs/cggcffhq" target="_blank">https://wandb.ai/jorgvt/segmentation_test/runs/cggcffhq</a><br/>Synced 4 W&B file(s), 2345 media file(s), 148 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20221128_095332-cggcffhq/logs</code>
